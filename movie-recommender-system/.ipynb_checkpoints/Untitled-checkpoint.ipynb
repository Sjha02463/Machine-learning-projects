# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")
credits = pd.read_csv("tmdb_5000_credits.csv")

# %%
movies.head(5000)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
print(movies.head(5000))
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
credits.head(1)['crew'].values
# Out:
# array(['[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James C
# ...

# %%
movies = movies.merge(credits,on='title')

# %%
movies = movies.merge(credits,on='title')
print(movies.shape)
# Out:
# (4821, 26)

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
type(credits)
# Out:
# pandas.core.frame.DataFrame

# %%
print(type(movies))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
movies.head(5000)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4816     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4817       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4818          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4819          0                                                 []
# 4820          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies.shape
# Out:
# (4821, 26)

# %%
#genre
#id
#keywords
#title
#overview
#cast
#crew
#we will avoid the numerical datas

# %%
movies['original_language'].value_counts()
#we cant keep this column as we can observe that en covers the 95 percent of movies and rest of the other languages comes in 5 percent that can create the data imbalances
# Out:
# original_language
# en    4520
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# ko      14
# it      14
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# id       2
# cs       2
# ta       2
# ro       2
# ar       2
# te       1
# hu       1
# xx       1
# af       1
# is       1
# tr       1
# vi       1
# pl       1
# nb       1
# ky       1
# no       1
# sl       1
# ps       1
# el       1
# Name: count, dtype: int64

# %%
#95 percent english movies and rest of them are 5% so this may caue the imbalanced datas so we wont take this

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4821 entries, 0 to 4820
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4821 non-null   int64
#  1   genres                4821 non-null   object
#  2   homepage              1715 non-null   object
#  3   id                    4821 non-null   int64
#  4   keywords              4821 non-null   object
#  5   original_language     4821 non-null   object
#  6   original_title        4821 non-null   object
#  7   overview              4818 non-null   object
#  8   popularity            4821 non-null   float64
#  9   production_companies  4821 non-null   object
#  10  production_countries  4821 non-null   object
#  11  release_date          4820 non-null   object
#  12  revenue               4821 non-null   int64
#  13  runtime               4819 non-null   float64
#  14  spoken_languages      4821 non-null   object
# ...

# %%
movies_df = pd.read_csv('tmdb_5000_movies.csv', names=['movie_id_x', 'movie_id_y', 'cast_x', 'crew_x', 'cast_y', 'crew_y', 'genres', 'title', 'keywords', 'overview'])
print(movies_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4804 entries, ('budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies') to ('0', '[{"id": 99, "name": "Documentary"}]', nan, '25975', '[{"id": 1523, "name": "obsession"}, {"id": 2249, "name": "camcorder"}, {"id": 9986, "name": "crush"}, {"id": 11223, "name": "dream girl"}]', 'en', 'My Date with Drew', "Ever since the second grade when he first saw her in E.T. The Extraterrestrial, Brian Herzlinger has had a crush on Drew Barrymore. Now, 20 years later he's decided to try to fulfill his lifelong dream by asking her for a date. There's one small problem: She's Drew Barrymore and he's, well, Brian Herzlinger, a broke 27-year-old aspiring filmmaker from New Jersey.", '1.929883', '[{"name": "rusty bear entertainment", "id": 87986}, {"name": "lucky crow films", "id": 87987}]')
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ...

# %%
print(movies_df.head())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                         movie_id_x  \
# budget    genres                                             homepage                                     id     keywords                                           original_language original_title                           overview                                           popularity production_companies                                                             production_countries
# ...

# %%
movies_df.isnull().sum()
# Out:
# movie_id_x      0
# movie_id_y      1
# cast_x          0
# crew_x          2
# cast_y          0
# crew_y          0
# genres        844
# title           0
# keywords        0
# overview        0
# dtype: int64

# %%
type(movies_df)
# Out:
# pandas.core.frame.DataFrame

# %%
most_common_genre = movies_df['genres'].mode()[0]  # Get the most frequent genre
movies_df['genres'] = movies_df['genres'].fillna(most_common_genre)  # Assign back to DataFrame

# %%
movies_df.fillna("Unknown", inplace=True)  # Replace NaNs with "Unknown"

# %%
print(movies_df.isnull().sum())  # Should print all zeros if no null values exist
# Out:
# movie_id_x    0
# movie_id_y    0
# cast_x        0
# crew_x        0
# cast_y        0
# crew_y        0
# genres        0
# title         0
# keywords      0
# overview      0
# dtype: int64

# %%
movies_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[0].genres
#this appears to be in a weird format as this is a list of dictionary
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
#'[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'
#We have to convert this into a format as:-
#['Action','Adventure','Fantasy','SciFi']:-Basically we can say that we have to convert it from lists of dictionary to list

# %%
#def convert(obj):#Here object is a string
   # L = []
    #for i in ast.literal_eval(obj):#After this operation this object will be converted from String to a list
       # L.append(i['name'])
    #return L

# %%
#String indices must be converted into number and for doing this we have a module present in python named ast and in ast module we have ti usethe function literal_eval(pass the value)

# %%
#import ast
#ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'
#)

# %%
#convert('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')

# %%
# Apply function to 'genres' column
#movies_df['genres'] = movies_df['genres'].fillna("[]").apply(convert)

# %%
import ast
def convert(text):
    l = []
    for i in ast.literal_eval(text):
        l.append (i['name'])
    return l

# %%
movies_df.dropna(inplace = True)

# %%
movies_df['geners'] = movies_df['genres'].apply(convert)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 movies_df['geners'] = movies_df['genres'].apply(convert)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
movies_df.head()
